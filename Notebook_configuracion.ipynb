# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/Workspace/Users/juancasilvape@gmail.com/kaggle_creds'

# %pip install kaggle

# %%
# !kaggle competitions download -c home-credit-default-risk -p /tmp/home_credit
# !unzip -o /tmp/home_credit/home-credit-default-risk.zip -d /tmp/home_credit

# %%
import shutil, os

origen = "/tmp/home_credit"
destino = "/Volumes/workspace/default/home_credit"

for f in os.listdir(origen):
    if f.endswith(".csv"):
        shutil.move(os.path.join(origen, f), os.path.join(destino, f))

os.listdir(destino)
